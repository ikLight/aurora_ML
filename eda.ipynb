# %%
import numpy as np
import pandas as pd
import json
import os

# %%
with open('data.json') as file:
    data = json.load(file)

data["total"]
# Out:
# 3349

# %%
len(data["items"])
# Out:
# 100

# %%
df = pd.read_csv('data.csv')

# %%
len(df)
# Out:
# 3349

# %%
df.user_name.unique()
# Out:
# array(['Sophia Al-Farsi', 'Fatima El-Tahir', 'Armand Dupont',
#        'Hans Müller', 'Layla Kawaguchi', 'Amina Van Den Berg',
#        'Vikram Desai', "Lily O'Sullivan", 'Lorenzo Cavalli',
#        'Thiago Monteiro'], dtype=object)

# %%
df.user_id.unique()
# Out:
# array(['cd3a350e-dbd2-408f-afa0-16a072f56d23',
#        'e35ed60a-5190-4a5f-b3cd-74ced7519b4a',
#        '23103ae5-38a8-4d82-af82-e9942aa4aefb',
#        '5b2e7346-eef5-445d-a063-6c5267f04bf8',
#        'fc15e14c-f56f-4137-a7cd-797f90b61c93',
#        'a1ac663a-277a-4782-a0ba-7efdca8ae2ee',
#        '130f1fb9-2ddf-4049-ad0e-9a270f0cb561',
#        '1a4b66ec-2fe6-46d8-9d6e-a81ec06bc5c5',
#        '5965bb48-a1d3-40d6-a746-c049d983bc76',
#        '6b6dc782-f40c-4224-b5d8-198a9070b097'], dtype=object)

# %%
df_sophia = df[df.user_name == 'Sophia Al-Farsi']

# %%
df_sophia.shape
# Out:
# (346, 5)
